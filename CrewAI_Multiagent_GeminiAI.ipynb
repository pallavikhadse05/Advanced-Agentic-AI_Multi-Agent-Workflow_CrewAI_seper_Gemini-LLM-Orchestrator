# %%
# !nvidia-smi
# Out:
# Wed May 13 05:58:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install crewai

# %%
# !pip install 'crewai[tools]'

# %%
# !pip install gradio

# %%
import os
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool

os.environ['GEMINI_API_KEY'] = 'use own api key'
os.environ['SERPER_API_KEY'] = 'use own api key'

search_tool = SerperDevTool()

teacher = Agent(role ='Teacher',
                goal = 'Explain concepts clearly step by step',
                backstory = 'Expereienced teacher who explain with example',
                llm = 'gemini-2.5-flash',
                verbose = True
                )
researcher = Agent(role = 'Researcher',
                   goal = 'Find latest information',
                   backstory = 'Expert in searching real-world data',
                   tools = [search_tool],
                   llm = 'gemini-2.5-flash',
                   verbose = True
                   )
simplifier = Agent(role = 'Simplifier',
                   goal = 'Make thing easy',
                   backstory = 'Breaks complex ideas into simple language',
                   llm = 'gemini-2.5-flash',
                   verbose = True
                   )
student = Agent(role = 'Student',
                goal = 'Take notes',
                backstory = 'Writes simple notes like learner',
                llm = 'gemini-2.5-flash',
                verbose = True
                )
examiner = Agent(role = 'Examiner',
                 goal = 'Create questions',
                 backstory = 'Tests understanding',
                 llm = 'gemini-2.5-flash',
                 verbose = True
                 )
topic = 'What is difference between agents vs agentic ai vs mcp vs generative ai'

task1 = Task(
    description = f'Explain{topic} in simple steps with example',
    expected_output= 'step-by-step explanation',
    agent = teacher
)
task2 = Task(
    description = f'search and find 3 important points about {topic}',
    expected_output= '3 clear points',
    agent = researcher
)
task3 = Task(
    description = f'Simlify the explanation of {topic}',
    expected_output= 'Very simple explanation',
    agent = simplifier
)
task4 = Task(
    description = f'Write a short notes on {topic} like a student',
    expected_output= 'Simple notes',
    agent = student
)
task5 = Task(
    description = f'Create 5 questions about {topic}',
    expected_output= '3 easy questions',
    agent = examiner
)

crew = Crew(
    agents=[teacher, simplifier, student, examiner],
    tasks=[task1, task2, task3, task4, task5],
    verbose=True
)

result = crew.kickoff()

print(result)
# Out:
# ╭───────────────────────── 🚀 Crew Execution Started ──────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: d0a11663-611b-416e-a4f7-9541e5fc28ca                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name: ExplainWhat is difference between agents vs agentic ai vs mcp vs      │
# │  generative ai in simple steps with example                                  │
# │  ID: 7ad5b832-5d89-40eb-ab3f-5beec4057cd2                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Teacher                                                              │
# │                                                                              │
# │  Task: ExplainWhat is difference between agents vs agentic ai vs mcp vs      │
# │  generative ai in simple steps with example                                  │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Teacher                                                              │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Hello there! As an experienced teacher, I'll break down these concepts      │
# │  step by step with clear examples to make sure you grasp the differences     │
# │  easily.                                                                     │
# │                                                                              │
# │  Let's dive in!                                                              │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  ### Understanding AI Concepts: Agents, Agentic AI, MCP, and Generative AI   │
# │                                                                              │
# │  We'll start with the foundational idea of an "Agent" and build up from      │
# │  there.                                                                      │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  #### 1. AI Agent                                                            │
# │                                                                              │
# │  **What it is:**                                                             │
# │  At its core, an AI Agent is an entity that perceives its environment        │
# │  through "sensors" and acts upon that environment through "effectors."       │
# │  Think of it as a system designed to achieve specific goals by making        │
# │  decisions based on what it senses. It follows a set of rules or             │
# │  algorithms.                                                                 │
# │                                                                              │
# │  **Key Characteristics:**                                                    │
# │  *   **Perceives:** Gathers information from its surroundings.               │
# │  *   **Decides:** Uses its internal logic/rules to process information.      │
# │  *   **Acts:** Takes actions in its environment.                             │
# │  *   **Goal-Oriented:** Tries to achieve a specific objective.               │
# │                                                                              │
# │  **Simple Step-by-Step Example: A Smart Thermostat**                         │
# │  1.  **Perceives:** It has a sensor that constantly checks the current room  │
# │  temperature.                                                                │
# │  2.  **Decides:** It compares the current temperature to the user-set        │
# │  desired temperature (its goal).                                             │
# │  3.  **Acts:**                                                               │
# │      *   If the room is too cold, it sends a signal to turn on the heater.   │
# │      *   If the room is too hot, it sends a signal to turn on the air        │
# │  conditioner.                                                                │
# │      *   If it's just right, it does nothing.                                │
# │  4.  **Goal:** Maintain the room at the desired temperature.                 │
# │                                                                              │
# │  This thermostat is a simple agent because it perceives, decides, and acts   │
# │  to achieve a goal.                                                          │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  #### 2. Agentic AI (or Agent-Based AI)                                      │
# │                                                                              │
# │  **What it is:**                                                             │
# │  Agentic AI takes the concept of an AI Agent to a much higher level. It      │
# │  refers to highly autonomous and proactive AI systems that can understand    │
# │  complex, high-level goals, break them down into smaller sub-tasks, plan     │
# │  and execute those sub-tasks, monitor their progress, and even adapt their   │
# │  strategy if things don't go as planned. They often leverage multiple AI     │
# │  tools or models to complete a multi-step objective.                         │
# │                                                                              │
# │  **Key Characteristics:**                                                    │
# │  *   **Autonomy:** Operates with minimal human intervention.                 │
# │  *   **Goal Decomposition:** Can break a big problem into smaller,           │
# │  manageable steps.                                                           │
# │  *   **Planning & Execution:** Creates a plan and then carries it out.       │
# │  *   **Monitoring & Adaptation:** Checks progress and adjusts the plan if    │
# │  needed.                                                                     │
# │  *   **Tool Use:** Can integrate and use different AI models (like           │
# │  generative AI models) or external tools (like web browsers, APIs).          │
# │                                                                              │
# │  **Simple Step-by-Step Example: An AI Travel Planner**                       │
# │  Imagine you tell an AI: "Plan a 7-day trip to Japan for me in October,      │
# │  focusing on culture and food, with a budget of around $3000, flying from    │
# │  New York."                                                                  │
# │                                                                              │
# │  1.  **Understand Complex Goal:** The AI understands "plan a trip to Japan"  │
# │  is a multi-faceted task.                                                    │
# │  2.  **Goal Decomposition:** It breaks it down:                              │
# │      *   Find flights (NY to Japan, round trip, October).                    │
# │      *   Find accommodation (7 nights, cultural areas, budget-friendly).     │
# │      *   Research cultural activities (temples, museums, traditional arts).  │
# │      *   Research food experiences (local restaurants, markets, cooking      │
# │  classes).                                                                   │
# │      *   Create a daily itinerary.                                           │
# │      *   Estimate total costs.                                               │
# │  3.  **Planning & Execution:**                                               │
# │      *   It might use a web search tool to find flight options.              │
# │      *   It might use a booking API to check hotel availability.             │
# │      *   It might use a large language model (a form of generative AI) to    │
# │  brainstorm cultural and food attractions in different cities (e.g., Tokyo,  │
# │  Kyoto).                                                                     │
# │      *   It generates a proposed itinerary, day by day.                      │
# │  4.  **Monitoring & Adaptation:**                                            │
# │      *   If flight prices are too high for October, it might suggest         │
# │  alternative dates or different airports.                                    │
# │      *   If a specific hotel is fully booked, it finds alternatives.         │
# │      *   It presents the plan to you and can make revisions based on your    │
# │  feedback.                                                                   │
# │  5.  **Output:** A complete, detailed itinerary with flight and hotel        │
# │  suggestions, activities, and estimated costs.                               │
# │                                                                              │
# │  This AI is "agentic" because it takes a high-level goal, plans, executes,   │
# │  and adapts autonomously.                                                    │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  #### 3. Generative AI                                                       │
# │                                                                              │
# │  **What it is:**                                                             │
# │  Generative AI is a type of AI that is specifically designed to *create*     │
# │  new content (text, images, audio, video, code, etc.) that is novel but      │
# │  stylistically and structurally similar to the data it was trained on. It    │
# │  learns patterns, styles, and structures from vast datasets and then uses    │
# │  that understanding to produce original outputs. Its primary function is     │
# │  creation, not necessarily acting in an environment or achieving a           │
# │  multi-step goal in the way an agent does.                                   │
# │                                                                              │
# │  **Key Characteristics:**                                                    │
# │  *   **Creation:** Produces new content.                                     │
# │  *   **Pattern Learning:** Learns underlying patterns from training data.    │
# │  *   **Novelty:** Generates outputs that didn't exist before.                │
# │  *   **Modalities:** Can work with text (LLMs), images (Diffusion Models),   │
# │  audio, etc.                                                                 │
# │                                                                              │
# │  **Simple Step-by-Step Example: An Image Generator (e.g., DALL-E,            │
# │  Midjourney)**                                                               │
# │  Imagine you ask an image generation AI: "Create an image of a cat wearing   │
# │  a spacesuit, floating in space with Earth in the background, in the style   │
# │  of a retro sci-fi comic."                                                   │
# │                                                                              │
# │  1.  **Input:** You provide a text prompt describing what you want.          │
# │  2.  **Pattern Recognition:** The AI has been trained on millions of images  │
# │  of cats, spacesuits, space, Earth, and retro sci-fi comics. It understands  │
# │  the visual features and stylistic elements associated with each.            │
# │  3.  **Generation:** It uses its learned patterns to synthesize a brand new  │
# │  image that combines these elements according to your prompt. It doesn't     │
# │  find an existing image; it *creates* one pixel by pixel.                    │
# │  4.  **Output:** A unique image of a cat in a spacesuit, floating in space,  │
# │  with Earth, rendered in a retro comic style.                                │
# │                                                                              │
# │  Generative AI's goal is to fulfill a creative request by synthesizing new   │
# │  data, not to execute a series of actions in an environment to achieve a     │
# │  larger objective.                                                           │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  #### 4. MCP (Multi-Agent Collaboration Platform / Multi-Agent System)       │
# │                                                                              │
# │  **What it is:**                                                             │
# │  MCP, in this context, most likely refers to a **Multi-Agent System** or a   │
# │  **Multi-Agent Collaboration Platform**. This is an environment where        │
# │  *multiple* individual AI agents (which could be simple agents or even       │
# │  agentic AIs) interact with each other and their shared environment to       │
# │  achieve individual goals or a collective system-wide goal. The complexity   │
# │  comes from the interactions and coordination between these different        │
# │  agents.                                                                     │
# │                                                                              │
# │  **Key Characteristics:**                                                    │
# │  *   **Multiple Agents:** Involves more than one AI agent.                   │
# │  *   **Interaction:** Agents communicate, cooperate, or even compete.        │
# │  *   **Shared Environment:** Agents operate within the same defined space    │
# │  or system.                                                                  │
# │  *   **Distributed Problem Solving:** Complex problems are broken down and   │
# │  handled by different agents.                                                │
# │  *   **Emergent Behavior:** The system's overall behavior can be more        │
# │  complex than the sum of its individual agents.                              │
# │                                                                              │
# │  **Simple Step-by-Step Example: A Smart Factory Floor**                      │
# │  Imagine a factory where various tasks are performed by different            │
# │  intelligent machines.                                                       │
# │                                                                              │
# │  1.  **Agent A (Robot Arm):** Perceives incoming raw materials, decides to   │
# │  pick them up, and places them on a conveyor belt. Its goal is "move raw     │
# │  materials."                                                                 │
# │  2.  **Agent B (Conveyor Belt System):** Perceives a part on its belt,       │
# │  decides to move it to the next station, and actuates the belt. Its goal is  │
# │  "transport parts."                                                          │
# │  3.  **Agent C (Quality Control Vision System):** Perceives the part as it   │
# │  moves past, decides if it meets quality standards, and might signal a       │
# │  defect. Its goal is "inspect parts."                                        │
# │  4.  **Agent D (Scheduling & Optimization AI):** Observes the status of      │
# │  Agents A, B, and C, predicts potential bottlenecks, and sends commands to   │
# │  adjust the speed of Agent A or B to optimize the overall production flow.   │
# │  Its goal is "maximize production efficiency."                               │
# │                                                                              │
# │  *   **Collaboration:** These agents are all working together, often         │
# │  communicating (e.g., Robot A tells Conveyor B it's placed a part; Vision C  │
# │  tells Scheduler D about a defect).                                          │
# │  *   **Shared Goal:** The collective goal is to efficiently manufacture a    │
# │  product.                                                                    │
# │  *   **Platform:** The factory floor itself, with its network and            │
# │  communication protocols, acts as the platform where these agents interact.  │
# │                                                                              │
# │  This system is an MCP because it involves multiple, distinct AI agents      │
# │  collaborating and interacting within a shared environment to achieve a      │
# │  larger system objective.                                                    │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  ### Key Differences Summarized:                                             │
# │                                                                              │
# │  | Feature           | AI Agent (Simple)                                     │
# │  | Agentic AI                                                   |            │
# │  Generative AI                                            | MCP              │
# │  (Multi-Agent System)                                   |                    │
# │  | :---------------- | :--------------------------------------------------   │
# │  | :----------------------------------------------------------- |            │
# │  :------------------------------------------------------- |                  │
# │  :--------------------------------------------------------- |                │
# │  | **Primary Focus** | Perceive, decide, act (single, simple goal)           │
# │  | Autonomously plan & execute complex, multi-step goals        | Create     │
# │  novel content (text, image, audio)                | Multiple agents         │
# │  interacting to achieve collective goals    |                                │
# │  | **Complexity**    | Low to medium                                         │
# │  | High (involves planning, adaptation, tool use)               | High       │
# │  (involves learning complex patterns to create)      | High (involves        │
# │  interaction and coordination of multiple agents) |                          │
# │  | **Autonomy**      | Limited (reacts to immediate environment)             │
# │  | High (can initiate actions, break down tasks)                | Low        │
# │  (creates based on prompt, doesn't "act" autonomously) | Can be high         │
# │  (individual agents autonomous, but interact)   |                            │
# │  | **Output**        | Actions in an environment (e.g., turn on/off)         │
# │  | Achieves a complex objective through a series of actions/steps | New      │
# │  creative content (e.g., an image, a story, code)     | A collective         │
# │  outcome or state achieved through interaction |                             │
# │  | **Example**       | Thermostat                                            │
# │  | AI travel planner                                            | DALL-E     │
# │  (image generator)                                 | Smart factory           │
# │  automation system                             |                             │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  I hope this detailed breakdown makes the distinctions clear! Let me know    │
# │  if you have any more questions.                                             │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: ExplainWhat is difference between agents vs agentic ai vs mcp vs      │
# │  generative ai in simple steps with example                                  │
# │  Agent: Teacher                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name: search and find 3 important points about What is difference between   │
# │  agents vs agentic ai vs mcp vs generative ai                                │
# │  ID: 0682cfd2-de48-463b-80b8-95a883f6932d                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Researcher                                                           │
# │                                                                              │
# │  Task: search and find 3 important points about What is difference between   │
# │  agents vs agentic ai vs mcp vs generative ai                                │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Researcher                                                           │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Here are 3 important points about the differences between AI Agents,        │
# │  Agentic AI, MCP, and Generative AI:                                         │
# │                                                                              │
# │  1.  **Primary Function/Goal:**                                              │
# │      *   An **AI Agent (Simple)**'s primary function is to perceive its      │
# │  environment, make simple decisions based on rules, and act to achieve a     │
# │  single, often immediate, goal (e.g., a thermostat maintaining a set         │
# │  temperature).                                                               │
# │      *   **Agentic AI** aims to autonomously plan and execute complex,       │
# │  multi-step goals by breaking them down into sub-tasks, leveraging various   │
# │  tools (which may include generative AI), and adapting its strategy if       │
# │  needed (e.g., an AI travel planner organizing an entire trip).              │
# │      *   **Generative AI** is specifically designed to *create* novel        │
# │  content (text, images, audio, code, etc.) that is original but              │
# │  stylistically similar to the data it was trained on, without necessarily    │
# │  performing actions in an environment to achieve a multi-step objective      │
# │  (e.g., an image generator creating a unique picture from a text prompt).    │
# │      *   An **MCP (Multi-Agent System)** focuses on enabling *multiple*      │
# │  individual AI agents to interact, communicate, and collaborate within a     │
# │  shared environment to achieve individual goals that collectively            │
# │  contribute to a larger, system-wide objective (e.g., a smart factory floor  │
# │  where different robots and systems coordinate manufacturing tasks).         │
# │                                                                              │
# │  2.  **Autonomy and Operational Complexity:**                                │
# │      *   **AI Agents (Simple)** exhibit limited autonomy, primarily          │
# │  reacting to immediate environmental changes according to their programmed   │
# │  rules.                                                                      │
# │      *   **Agentic AI** possesses high autonomy, capable of initiating       │
# │  actions, understanding and decomposing high-level objectives, planning a    │
# │  sequence of operations, and adaptively managing the execution process.      │
# │      *   **Generative AI** has low operational autonomy in terms of          │
# │  "acting" or executing a sequence of steps in an environment; its            │
# │  complexity lies in learning vast patterns to synthesize new data, but its   │
# │  function is typically a direct response to a creative prompt.               │
# │      *   The **MCP** introduces complexity through the interaction and       │
# │  coordination dynamics among its multiple, potentially autonomous, agents,   │
# │  where the overall system behavior often emerges from these interactions.    │
# │                                                                              │
# │  3.  **Nature of Output/Result:**                                            │
# │      *   The output of an **AI Agent (Simple)** is a direct action or set    │
# │  of actions performed within its environment (e.g., turning a heater on or   │
# │  off) to achieve or maintain a specific state.                               │
# │      *   **Agentic AI** produces a comprehensive solution or fulfills a      │
# │  complex, high-level objective through a managed sequence of actions, often  │
# │  involving the integration and use of various tools and sub-models.          │
# │      *   **Generative AI**'s output is new, creative content—a unique piece  │
# │  of text, an image, a sound clip, or code—that did not exist prior to its    │
# │  creation.                                                                   │
# │      *   The **MCP** yields a collective outcome or a desired system state   │
# │  achieved through the combined, and often synchronized, efforts and          │
# │  interactions of all its constituent agents.                                 │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: search and find 3 important points about What is difference between   │
# │  agents vs agentic ai vs mcp vs generative ai                                │
# │  Agent: Researcher                                                           │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name: Simlify the explanation of What is difference between agents vs       │
# │  agentic ai vs mcp vs generative ai                                          │
# │  ID: 9d5d5101-c598-4d0f-aea3-6b173f12e86a                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Simplifier                                                           │
# │                                                                              │
# │  Task: Simlify the explanation of What is difference between agents vs       │
# │  agentic ai vs mcp vs generative ai                                          │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Simplifier                                                           │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Hello there! As an experienced teacher, I'll break down these concepts      │
# │  step by step with clear examples to make sure you grasp the differences     │
# │  easily.                                                                     │
# │                                                                              │
# │  Let's dive in!                                                              │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  ### Understanding AI Concepts: Agents, Agentic AI, MCP, and Generative AI   │
# │                                                                              │
# │  We'll start with the foundational idea of an "Agent" and build up from      │
# │  there.                                                                      │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  #### 1. AI Agent                                                            │
# │                                                                              │
# │  **What it is:**                                                             │
# │  Think of an AI Agent as a tiny, smart worker. It *sees* things around it    │
# │  (like sensors), *thinks* about what it sees (makes decisions), and then     │
# │  *does* something (takes action) to reach a simple goal. It follows a set    │
# │  of rules.                                                                   │
# │                                                                              │
# │  **Key Characteristics:**                                                    │
# │  *   **Sees:** Gathers information from its surroundings.                    │
# │  *   **Thinks:** Uses its rules to process information.                      │
# │  *   **Acts:** Takes actions in its environment.                             │
# │  *   **Goal-Oriented:** Tries to achieve a specific objective.               │
# │                                                                              │
# │  **Simple Step-by-Step Example: A Smart Thermostat**                         │
# │  1.  **Sees:** It has a sensor that constantly checks the current room       │
# │  temperature.                                                                │
# │  2.  **Thinks:** It compares the current temperature to the temperature you  │
# │  want (its goal).                                                            │
# │  3.  **Acts:**                                                               │
# │      *   If the room is too cold, it turns on the heater.                    │
# │      *   If the room is too hot, it turns on the air conditioner.            │
# │      *   If it's just right, it does nothing.                                │
# │  4.  **Goal:** Keep the room at the temperature you set.                     │
# │                                                                              │
# │  This thermostat is a simple agent because it sees, thinks, and acts to      │
# │  achieve a goal.                                                             │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  #### 2. Agentic AI (or Agent-Based AI)                                      │
# │                                                                              │
# │  **What it is:**                                                             │
# │  Agentic AI is like an AI project manager. Instead of just doing a simple,   │
# │  immediate task, it can handle *big, complicated goals*. It figures out how  │
# │  to *break a big task into smaller steps*, *makes a plan*, *does those       │
# │  steps*, *checks its progress*, and even *changes the plan* if things go     │
# │  wrong. It often uses many different AI tools to get the whole job done.     │
# │                                                                              │
# │  **Key Characteristics:**                                                    │
# │  *   **Works Alone:** Can operate without much human help.                   │
# │  *   **Breaks Down Goals:** Can turn a big problem into smaller, easier      │
# │  steps.                                                                      │
# │  *   **Plans & Does:** Creates a plan and then carries it out.               │
# │  *   **Checks & Adjusts:** Watches how things are going and changes the      │
# │  plan if needed.                                                             │
# │  *   **Uses Tools:** Can use other AI models (like generative AI) or online  │
# │  tools (like web browsers).                                                  │
# │                                                                              │
# │  **Simple Step-by-Step Example: An AI Travel Planner**                       │
# │  Imagine you tell an AI: "Plan a 7-day trip to Japan for me in October,      │
# │  focusing on culture and food, with a budget of around $3000, flying from    │
# │  New York."                                                                  │
# │                                                                              │
# │  1.  **Understands Big Goal:** The AI understands "plan a trip to Japan" is  │
# │  a multi-part project.                                                       │
# │  2.  **Breaks Down Goal:** It splits the big goal into smaller tasks:        │
# │      *   Find flights (NY to Japan, in October).                             │
# │      *   Find places to stay (7 nights, cultural areas, within budget).      │
# │      *   Research cultural things to do (temples, museums).                  │
# │      *   Research food spots (restaurants, cooking classes).                 │
# │      *   Create a day-by-day plan.                                           │
# │      *   Estimate total costs.                                               │
# │  3.  **Plans & Does:**                                                       │
# │      *   It might use a web search tool to find flights.                     │
# │      *   It might use a hotel booking tool to check rooms.                   │
# │      *   It might use a generative AI (like a smart chatbot) to brainstorm   │
# │  fun things to do in Tokyo and Kyoto.                                        │
# │      *   It then puts together a suggested daily plan.                       │
# │  4.  **Checks & Adjusts:**                                                   │
# │      *   If flights are too expensive, it might suggest different dates.     │
# │      *   If a hotel is full, it finds another one.                           │
# │      *   It shows you the plan and can change it if you have feedback.       │
# │  5.  **Output:** A complete, detailed plan for your trip with flights,       │
# │  hotels, activities, and costs.                                              │
# │                                                                              │
# │  This AI is "agentic" because it takes a big goal, plans, does, and adjusts  │
# │  everything on its own.                                                      │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  #### 3. Generative AI                                                       │
# │                                                                              │
# │  **What it is:**                                                             │
# │  Generative AI is the *creator*. It's a type of AI that learns from huge     │
# │  amounts of existing stuff (like millions of pictures, books, or songs).     │
# │  Then, it uses what it learned to *make brand new content* that never        │
# │  existed before. This could be new text, new images, new music, or even new  │
# │  computer code. Its main job is to create, not to act in the world or plan   │
# │  big tasks like an agent.                                                    │
# │                                                                              │
# │  **Key Characteristics:**                                                    │
# │  *   **Creates:** Produces brand new content.                                │
# │  *   **Learns Patterns:** Understands the style and structure from the data  │
# │  it was trained on.                                                          │
# │  *   **Makes New Things:** Generates outputs that are original.              │
# │  *   **Different Types:** Can create text (like ChatGPT), images (like       │
# │  DALL-E), sounds, and more.                                                  │
# │                                                                              │
# │  **Simple Step-by-Step Example: An Image Generator (e.g., DALL-E,            │
# │  Midjourney)**                                                               │
# │  Imagine you ask an image generation AI: "Create an image of a fluffy cat    │
# │  wearing a spacesuit, floating in space with Earth behind it, in the style   │
# │  of an old comic book."                                                      │
# │                                                                              │
# │  1.  **Input:** You type your request (a text prompt).                       │
# │  2.  **Learns Patterns:** The AI has seen millions of pictures of cats,      │
# │  spacesuits, space, Earth, and old comic books. It understands what all      │
# │  these things look like and how different styles work.                       │
# │  3.  **Generates:** It uses this knowledge to *draw* a brand new image,      │
# │  pixel by pixel, combining all your ideas. It doesn't find an existing       │
# │  picture; it *creates* one from scratch.                                     │
# │  4.  **Output:** A unique picture of a fluffy cat in a spacesuit, floating   │
# │  in space with Earth, all drawn in a retro comic book style.                 │
# │                                                                              │
# │  Generative AI's goal is to fulfill a creative request by making new data,   │
# │  not to do a series of actions in the real world to reach a bigger           │
# │  objective.                                                                  │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  #### 4. MCP (Multi-Agent Collaboration Platform / Multi-Agent System)       │
# │                                                                              │
# │  **What it is:**                                                             │
# │  MCP, in simple terms, means a **team of AI agents working together**. It's  │
# │  a place where *many individual AI agents* (which could be simple agents or  │
# │  even Agentic AIs) all interact with each other and their shared             │
# │  environment to achieve their own small goals, which then add up to one big  │
# │  team goal. The trick is how they all talk to and coordinate with each       │
# │  other.                                                                      │
# │                                                                              │
# │  **Key Characteristics:**                                                    │
# │  *   **Many Agents:** Involves more than one AI agent.                       │
# │  *   **Talk & Work Together:** Agents communicate, cooperate, or even        │
# │  compete.                                                                    │
# │  *   **Shared Space:** Agents operate within the same defined area or        │
# │  system.                                                                     │
# │  *   **Big Problem, Many Hands:** Complex problems are broken down, and      │
# │  different agents handle different parts.                                    │
# │  *   **Team Result:** The overall behavior of the system comes from all the  │
# │  agents working together.                                                    │
# │                                                                              │
# │  **Simple Step-by-Step Example: A Smart Factory Floor**                      │
# │  Imagine a factory where various jobs are done by different smart machines   │
# │  and AI systems.                                                             │
# │                                                                              │
# │  1.  **Agent A (Robot Arm):** Sees raw materials, picks them up, and puts    │
# │  them on a conveyor belt. Its goal is "move raw materials."                  │
# │  2.  **Agent B (Conveyor Belt System):** Sees a part on its belt, moves it   │
# │  to the next station. Its goal is "transport parts."                         │
# │  3.  **Agent C (Quality Control Camera AI):** Sees the part as it moves by,  │
# │  decides if it looks good, and might alert if there's a problem. Its goal    │
# │  is "check quality."                                                         │
# │  4.  **Agent D (Scheduling AI):** Watches what Agents A, B, and C are        │
# │  doing, predicts if there will be traffic jams, and tells Agent A or B to    │
# │  speed up or slow down to keep everything running smoothly. Its goal is      │
# │  "make production as fast as possible."                                      │
# │                                                                              │
# │  *   **Teamwork:** These agents are all working together, often telling      │
# │  each other what's happening (e.g., Robot A tells Conveyor B it has placed   │
# │  a part; Camera C tells Scheduler D about a defect).                         │
# │  *   **Shared Goal:** The collective goal is to efficiently build a          │
# │  product.                                                                    │
# │  *   **Platform:** The factory floor itself, with its network, is the        │
# │  "platform" where these agents interact.                                     │
# │                                                                              │
# │  This system is an MCP because it involves multiple, distinct AI agents      │
# │  collaborating and interacting within a shared environment to achieve a      │
# │  larger system objective.                                                    │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  ### Key Differences Summarized:                                             │
# │                                                                              │
# │  | Feature           | AI Agent (Simple)                                     │
# │  | Agentic AI                                                    |           │
# │  Generative AI                                             | MCP             │
# │  (Multi-Agent System)                                   |                    │
# │  | :---------------- | :---------------------------------------------------  │
# │  | :------------------------------------------------------------ |           │
# │  :-------------------------------------------------------- |                 │
# │  :--------------------------------------------------------- |                │
# │  | **Main Job**      | Perceive, decide, act (for a simple, immediate goal)  │
# │  | Plan & execute complex, multi-step goals (like a project manager) |       │
# │  Create brand new content (text, image, audio)             | Many agents     │
# │  interacting for a big team goal                |                            │
# │  | **Complexity**    | Basic                                                 │
# │  | Smart Planner (high-level thinking, uses tools)               | Creative  │
# │  Learner (learns patterns to create)              | Team Manager             │
# │  (coordinates many interacting parts)          |                             │
# │  | **Autonomy**      | Just reacts to what it sees                           │
# │  | Takes charge (makes plans, adapts on its own)                 | Needs a   │
# │  prompt (creates based on your request, doesn't act) | Team works together   │
# │  (individual parts are smart, but interact) |                                │
# │  | **What it does**  | Takes a direct action (e.g., turns something on/off)  │
# │  | Completes a whole complex objective through steps             | Makes     │
# │  something completely new (e.g., a unique picture)   | A collective outcome  │
# │  or a smoothly running system          |                                     │
# │  | **Example**       | Smart Thermostat                                      │
# ...
# │  efficiently).                                                               │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: Simlify the explanation of What is difference between agents vs       │
# │  agentic ai vs mcp vs generative ai                                          │
# │  Agent: Simplifier                                                           │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name: Write a short notes on What is difference between agents vs agentic   │
# │  ai vs mcp vs generative ai like a student                                   │
# │  ID: 49fdfdbd-eafc-41ac-8261-74a1f7b1e34e                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Student                                                              │
# │                                                                              │
# │  Task: Write a short notes on What is difference between agents vs agentic   │
# │  ai vs mcp vs generative ai like a student                                   │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Student                                                              │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Here are my notes on the differences:                                       │
# │                                                                              │
# │  **AI Agent (Simple)**                                                       │
# │  *   **What it is:** Like a small smart worker. It sees things, follows      │
# │  simple rules to decide, and then acts to reach one simple goal.             │
# │  *   **Example:** A smart thermostat. It sees the room temp, thinks if it's  │
# │  too hot/cold, and turns on the heater/AC.                                   │
# │  *   **Main Job:** Do one simple task based on what it senses.               │
# │                                                                              │
# │  **Agentic AI**                                                              │
# │  *   **What it is:** Like an AI project manager. It takes a *big, complex    │
# │  goal*, breaks it into small steps, makes a plan, does the steps, checks if  │
# │  it's working, and changes the plan if needed. It can use other tools (even  │
# │  Generative AI!).                                                            │
# │  *   **Example:** An AI that plans your whole 7-day trip to Japan (finds     │
# │  flights, hotels, activities, budget).                                       │
# │  *   **Main Job:** Plan and finish a whole big project by itself.            │
# │                                                                              │
# │  **Generative AI**                                                           │
# │  *   **What it is:** The "creator" AI. It learns from tons of existing       │
# │  stuff (like pictures or text) and then *makes completely new things* that   │
# │  didn't exist before.                                                        │
# │  *   **Example:** DALL-E or Midjourney. You tell it "cat in spacesuit," and  │
# │  it draws a new picture of it.                                               │
# │  *   **Main Job:** Create brand new content (like text, pictures, music).    │
# │                                                                              │
# │  **MCP (Multi-Agent Collaboration Platform / Multi-Agent System)**           │
# │  *   **What it is:** A *team of many AI agents* working together in the      │
# │  same place. Each agent has its own job, but they talk and work together to  │
# │  achieve one big team goal.                                                  │
# │  *   **Example:** A smart factory floor. Different robots (Agent A, B, C)    │
# │  and a scheduling AI (Agent D) all work together to build products           │
# │  efficiently.                                                                │
# │  *   **Main Job:** Get many different AI agents to cooperate and achieve a   │
# │  big team goal.                                                              │
# │                                                                              │
# │  ---                                                                         │
# │                                                                              │
# │  **Simple Differences Summary:**                                             │
# │                                                                              │
# │  *   **AI Agent (Simple):** Does one basic task (like thermostat).           │
# │  *   **Agentic AI:** Plans and does complex projects on its own (like        │
# │  travel planner).                                                            │
# │  *   **Generative AI:** Makes new things (like unique pictures or stories).  │
# │  *   **MCP:** A team of AIs working together for a shared big goal (like a   │
# │  smart factory).                                                             │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: Write a short notes on What is difference between agents vs agentic   │
# │  ai vs mcp vs generative ai like a student                                   │
# │  Agent: Student                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name: Create 5 questions about What is difference between agents vs         │
# │  agentic ai vs mcp vs generative ai                                          │
# │  ID: e3ac722c-e3d5-413b-918b-251f180cebca                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Examiner                                                             │
# │                                                                              │
# │  Task: Create 5 questions about What is difference between agents vs         │
# │  agentic ai vs mcp vs generative ai                                          │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Examiner                                                             │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Here are 5 questions based on the provided text, with 3 easy ones as        │
# │  requested:                                                                  │
# │                                                                              │
# │  **Easy Questions:**                                                         │
# │                                                                              │
# │  1.  According to the text, what is the primary function of a simple AI      │
# │  Agent?                                                                      │
# │  2.  Which type of AI is specifically designed to *create* new content such  │
# │  as text, images, or audio?                                                  │
# │  3.  What does the acronym MCP stand for in the context of AI, as described  │
# │  in the text?                                                                │
# │                                                                              │
# │  **Medium Questions:**                                                       │
# │                                                                              │
# │  4.  How does an Agentic AI's approach to achieving goals differ from that   │
# │  of a simple AI Agent, particularly in terms of complexity and autonomy?     │
# │  5.  Based on the examples given, how can a Generative AI be utilized as a   │
# │  "tool" by an Agentic AI system?                                             │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭───────────────────────────── 📋 Task Completion ─────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: Create 5 questions about What is difference between agents vs         │
# │  agentic ai vs mcp vs generative ai                                          │
# │  Agent: Examiner                                                             │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Here are 5 questions based on the provided text, with 3 easy ones as requested:
#
# **Easy Questions:**
#
# 1.  According to the text, what is the primary function of a simple AI Agent?
# 2.  Which type of AI is specifically designed to *create* new content such as text, images, or audio?
# 3.  What does the acronym MCP stand for in the context of AI, as described in the text?
#
# **Medium Questions:**
#
# 4.  How does an Agentic AI's approach to achieving goals differ from that of a simple AI Agent, particularly in terms of complexity and autonomy?
# 5.  Based on the examples given, how can a Generative AI be utilized as a "tool" by an Agentic AI system?
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: d0a11663-611b-416e-a4f7-9541e5fc28ca                                    │
# │  Final Output: Here are 5 questions based on the provided text, with 3 easy  │
# │  ones as requested:                                                          │
# │                                                                              │
# │  **Easy Questions:**                                                         │
# │                                                                              │
# │  1.  According to the text, what is the primary function of a simple AI      │
# │  Agent?                                                                      │
# │  2.  Which type of AI is specifically designed to *create* new content such  │
# │  as text, images, or audio?                                                  │
# │  3.  What does the acronym MCP stand for in the context of AI, as described  │
# │  in the text?                                                                │
# │                                                                              │
# │  **Medium Questions:**                                                       │
# │                                                                              │
# │  4.  How does an Agentic AI's approach to achieving goals differ from that   │
# │  of a simple AI Agent, particularly in terms of complexity and autonomy?     │
# │  5.  Based on the examples given, how can a Generative AI be utilized as a   │
# │  "tool" by an Agentic AI system?                                             │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
# use Gradio
import os
import gradio as gr
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool

os.environ['GEMINI_API_KEY'] = 'use own api key'
os.environ['SERPER_API_KEY'] = 'use own api key'

search_tool = SerperDevTool()

def run_multi_agent(topic):
  teacher = Agent(role ='Teacher',
                goal ='Explain concepts clearly step by step',
                backstory = 'Experienced teacher who explain with example',
                llm = 'gemini-2.5-flash',
                verbose = True)
  researcher = Agent(role = 'Researcher',
                   goal='Find latest information',
                   backstory = 'Expert in searching real-world data',
                   tools=[search_tool],
                   llm = 'gemini-2.5-flash',
                   verbose = True)
  simplifier = Agent(role = 'Simplifier',
                   goal = 'Make thing easy',
                   backstory = 'Breaks complex ideas into simple language',
                   llm = 'gemini-2.5-flash',
                   verbose=True)
  student = Agent(role= 'Student',
                goal = 'Take notes',
                backstory = 'Writes simple notes like learner',
                llm = 'gemini-2.5-flash',
                verbose = True)
  examiner = Agent (role = 'Examiner',
                 goal= 'Create questions',
                 backstory = 'Tests understanding',
                 llm = 'gemini-2.5-flash',
                 verbose=True)

  task1 = Task(
    description = f'Explain{topic} in simple steps with examples',
    expected_output= 'step-by-step explanation',
    agent = teacher)

  task2 = Task(
    description = f'search and find 3 important points about {topic}',
    expected_output = '3 clear points',
    agent = researcher)

  task3 = Task(
    description = f'Simplify the explanation of {topic}',
    expected_output='Very simple explanation',
    agent = simplifier )

  task4 = Task(
    description=f'Write short notes on {topic} like a student',
    expected_output='Simple notes',
    agent= student)

  task5 = Task(
    description=f'Create 5 questions about {topic}',
    expected_output='3 easy questions',
    agent=examiner)

  crew = Crew(
      agents=[teacher, researcher, simplifier, student, examiner],
      tasks=[task1, task2, task3, task4, task5],
      verbose=False)

  result = crew.kickoff()

  return str(result)

interface = gr.Interface(
    fn = run_multi_agent,
    inputs = gr.Textbox(
        label = 'Enter Topic',
        placeholder = 'what is Agentic AI vs single '),
    outputs = gr.Textbox(label = 'Multi-Agent Output'),
    title = 'Pallavi Khadse MultiAgent AI Training',
    description = 'Enter any topic and see multiple AI agents colabotate to teach, simplify and test you'

)

if __name__ == '__main__':
  interface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://58a8fdcea66eeebcc8.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://58a8fdcea66eeebcc8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
